# %% [markdown]
# **Cleaning of Home Health Care Data and Creating Single Spreadsheet**
# ***
# The goal of this cleaning is to join the ratings spreadsheet with additional ratings into a single spreadsheet.<br>
# Furthermore, columns will be renamed for ease of use.<br>
# By the end of this cleaning all clean spreadsheets will be merged into a final spreadsheet for analysis.

# %%
# Importing Necessary Tools
import pandas as pd
import numpy as np

# %%
# ImportDataFrames for Cleaning
df_rate = pd.read_csv('HHC_Rate.csv')
df_add = pd.read_csv('HHC_Report.csv')
df_cleaned = pd.read_csv('Readmissions_Cleaned.csv')

# %%
df_rate.head()
# Out:
#   State  Quality of Patient Care Star Rating  \
# 0    AK                                  2.5
# 1    AL                                  3.5
# 2    AR                                  3.0
# 3    AZ                                  3.5
# 4    CA                                  3.5
#
#    How often the home health team began their patients’ care in a timely manner  \
# 0                                               76.7
# 1                                               94.3
# 2                                               94.3
# 3                                               93.4
# 4                                               90.3
#
#    How often the home health team taught patients (or their family caregivers) about their drugs  \
# 0                                               94.5
# 1                                               97.8
# 2                                               95.9
# 3                                               96.9
# 4                                               97.2
#
#    How often the home health team checked patients’ risk of falling  \
# 0                                               99.4
# 1                                               99.6
# 2                                               99.5
# 3                                               99.4
# 4                                               99.1
#
#    How often the home health team checked patients for depression  \
# 0                                               93.9
# 1                                               98.4
# 2                                               98.6
# 3                                               97.3
# 4                                               97.7
#
#    How often the home health team made sure that their patients have received a flu shot for the current flu season.  \
# 0                                               64.7
# 1                                               72.4
# 2                                               75.0
# 3                                               74.9
# 4                                               73.6
#
#    How often the home health team made sure that their patients have received a pneumococcal vaccine (pneumonia shot).  \
# 0                                               74.4
# 1                                               73.3
# 2                                               78.4
# 3                                               77.4
# 4                                               74.8
#
#    With diabetes, how often the home health team got doctor’s orders, gave foot care, and taught patients about foot care  \
# 0                                               96.1
# 1                                               96.9
# 2                                               96.7
# 3                                               97.2
# 4                                               97.0
#
#    How often the home health team checked patients for pain  \
# 0                                               97.5
# 1                                               99.6
# 2                                               99.3
# 3                                               98.7
# 4                                               98.9
#
#                                                        ...                                                       \
# 0                                                      ...
# 1                                                      ...
# 2                                                      ...
# 3                                                      ...
# 4                                                      ...
#
#    How often the home health team checked patients for the risk of developing pressure sores (bed sores)  \
# 0                                               99.4
# 1                                               99.5
# 2                                               99.2
# 3                                               98.9
# 4                                               98.5
#
#    How often patients got better at walking or moving around  \
# 0                                               55.6
# 1                                               72.9
# 2                                               71.1
# 3                                               63.1
# 4                                               66.1
#
#    How often patients got better at getting in and out of bed  \
# 0                                               54.0
# 1                                               66.7
# 2                                               67.8
# 3                                               61.6
# 4                                               62.0
#
#    How often patients got better at bathing  \
# 0                                      61.4
# 1                                      77.3
# 2                                      76.1
# 3                                      70.7
# 4                                      71.4
#
#    How often patients had less pain when moving around  \
# 0                                               55.1
# 1                                               75.6
# 2                                               71.9
# 3                                               67.8
# 4                                               75.2
#
#    How often patients’ breathing improved  \
# 0                                    58.8
# 1                                    74.5
# 2                                    71.7
# 3                                    71.3
# 4                                    71.9
#
#    How often patients’ wounds improved or healed after an operation  \
# 0                                               80.4
# 1                                               91.3
# 2                                               91.8
# 3                                               85.8
# 4                                               91.9
#
#    How often patients got better at taking their drugs correctly by mouth  \
# 0                                               45.8
# 1                                               62.5
# 2                                               61.1
# 3                                               55.2
# 4                                               55.5
#
#    How often home health patients had to be admitted to the hospital  \
# 0                                               14.2
# 1                                               17.5
# 2                                               17.4
# 3                                               14.9
# 4                                               14.8
#
#    How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted
# 0                                               17.3
# 1                                               12.2
# 2                                               13.4
# 3                                               13.5
# 4                                               11.9
#
# [5 rows x 24 columns]

# %%
df_add.head()
# Out:
#   State  \
# 0    AK
# 1    AL
# 2    AR
# 3    AZ
# 4    CA
#
#    Percent of patients who reported that their home health team gave care in a professional way  \
# 0                                                 89
# 1                                                 91
# 2                                                 90
# 3                                                 87
# 4                                                 85
#
#    Percent of patients who reported that their home health team communicated well with them  \
# 0                                                 85
# 1                                                 89
# 2                                                 87
# 3                                                 84
# 4                                                 83
#
#    Percent of patients who reported that their home health team discussed medicines, pain, and home safety with them  \
# 0                                                 81
# 1                                                 87
# 2                                                 86
# 3                                                 80
# 4                                                 82
#
#    Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)  \
# 0                                                 82
# 1                                                 89
# 2                                                 87
# 3                                                 81
# 4                                                 80
#
#    Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family  \
# 0                                                 81
# 1                                                 84
# 2                                                 83
# 3                                                 75
# 4                                                 74
#
#    Number of completed Surveys  Response rate
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN

# %%
# As You Can See the Column Names Are Too Long.  We'll Take Care of That After We Join the
# Two Tables and Drop the Last Two NaN-Filled Columns.

df = pd.merge(df_rate,df_add, on = 'State')
df = df.dropna(axis=1)

# %%
# Checking to Ensure Only Two Columns Were Dropped.  Expected Amount is 29 Columns.
# Also Checking to Ensure US Territories Are Dropped in the Merge.  Expected Amount is 51 Rows.
df.shape
# Out:
# (51, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 29 columns):
# State                                                                                                                     51 non-null object
# Quality of Patient Care Star Rating                                                                                       51 non-null float64
# How often the home health team began their patients’ care in a timely manner                                              51 non-null float64
# How often the home health team taught patients (or their family caregivers) about their drugs                             51 non-null float64
# How often the home health team checked patients’ risk of falling                                                          51 non-null float64
# How often the home health team checked patients for depression                                                            51 non-null float64
# How often the home health team made sure that their patients have received a flu shot for the current flu season.         51 non-null float64
# How often the home health team made sure that their patients have received a pneumococcal vaccine (pneumonia shot).       51 non-null float64
# With diabetes, how often the home health team got doctor’s orders, gave foot care, and taught patients about foot care    51 non-null float64
# How often the home health team checked patients for pain                                                                  51 non-null float64
# How often the home health team treated their patients’ pain                                                               51 non-null float64
# How often the home health team treated heart failure (weakening of the heart) patients’ symptoms                          51 non-null float64
# How often the home health team took doctor-ordered action to prevent pressure sores (bed sores)                           51 non-null float64
# How often the home health team included treatments to prevent pressure sores (bed sores) in the plan of care              51 non-null float64
# How often the home health team checked patients for the risk of developing pressure sores (bed sores)                     51 non-null float64
# How often patients got better at walking or moving around                                                                 51 non-null float64
# How often patients got better at getting in and out of bed                                                                51 non-null float64
# How often patients got better at bathing                                                                                  51 non-null float64
# How often patients had less pain when moving around                                                                       51 non-null float64
# How often patients’ breathing improved                                                                                    51 non-null float64
# How often patients’ wounds improved or healed after an operation                                                          51 non-null float64
# How often patients got better at taking their drugs correctly by mouth                                                    51 non-null float64
# How often home health patients had to be admitted to the hospital                                                         51 non-null float64
# How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted              51 non-null float64
# Percent of patients who reported that their home health team gave care in a professional way                              51 non-null int64
# Percent of patients who reported that their home health team communicated well with them                                  51 non-null int64
# Percent of patients who reported that their home health team discussed medicines, pain, and home safety with them         51 non-null int64
# Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)      51 non-null int64
# Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family        51 non-null int64
# dtypes: float64(23), int64(5), object(1)
# memory usage: 12.0+ KB

# %%
# Creating List and Renaming Columns
col = ['state','star_rating','timeliness','rx_ed','fall_risk','depression_check','flu_shot',
      'pneumonia_shot','d_foot_care','pain_check','pain_treat','heart_f_treat','p_sore_action',
      'p_sore_intreat','p_sore_check','move_buff','in_out_bed_buff','bathing_buff','move_pain_debuff',
      'breathing_buff','healing_buff','oral_rx_buff','hospital_admit','urgent_noadmit',
      'pos_prof_report','pos_communicate_report','pos_treatment_ed_report','nine_to_ten_rate',
      'would_recommend']
df.columns=col

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 29 columns):
# state                      51 non-null object
# star_rating                51 non-null float64
# timeliness                 51 non-null float64
# rx_ed                      51 non-null float64
# fall_risk                  51 non-null float64
# depression_check           51 non-null float64
# flu_shot                   51 non-null float64
# pneumonia_shot             51 non-null float64
# d_foot_care                51 non-null float64
# pain_check                 51 non-null float64
# pain_treat                 51 non-null float64
# heart_f_treat              51 non-null float64
# p_sore_action              51 non-null float64
# p_sore_intreat             51 non-null float64
# p_sore_check               51 non-null float64
# move_buff                  51 non-null float64
# in_out_bed_buff            51 non-null float64
# bathing_buff               51 non-null float64
# move_pain_debuff           51 non-null float64
# breathing_buff             51 non-null float64
# healing_buff               51 non-null float64
# oral_rx_buff               51 non-null float64
# hospital_admit             51 non-null float64
# urgent_noadmit             51 non-null float64
# pos_prof_report            51 non-null int64
# pos_communicate_report     51 non-null int64
# pos_treatment_ed_report    51 non-null int64
# nine_to_ten_rate           51 non-null int64
# would_recommend            51 non-null int64
# dtypes: float64(23), int64(5), object(1)
# memory usage: 12.0+ KB

# %%
# Final Completely Merged DataFrame
final = pd.merge(df_cleaned,df, on='state')
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 37 columns):
# Unnamed: 0                 51 non-null int64
# state                      51 non-null object
# hospital_count             51 non-null int64
# readmission_ratio          51 non-null float64
# discharges                 51 non-null float64
# predicted_rate             51 non-null float64
# expected_rate              51 non-null float64
# readmissions               51 non-null float64
# excessive_count            51 non-null int64
# star_rating                51 non-null float64
# timeliness                 51 non-null float64
# rx_ed                      51 non-null float64
# fall_risk                  51 non-null float64
# depression_check           51 non-null float64
# flu_shot                   51 non-null float64
# pneumonia_shot             51 non-null float64
# d_foot_care                51 non-null float64
# pain_check                 51 non-null float64
# pain_treat                 51 non-null float64
# heart_f_treat              51 non-null float64
# p_sore_action              51 non-null float64
# p_sore_intreat             51 non-null float64
# p_sore_check               51 non-null float64
# move_buff                  51 non-null float64
# in_out_bed_buff            51 non-null float64
# bathing_buff               51 non-null float64
# move_pain_debuff           51 non-null float64
# breathing_buff             51 non-null float64
# healing_buff               51 non-null float64
# oral_rx_buff               51 non-null float64
# hospital_admit             51 non-null float64
# urgent_noadmit             51 non-null float64
# pos_prof_report            51 non-null int64
# pos_communicate_report     51 non-null int64
# pos_treatment_ed_report    51 non-null int64
# nine_to_ten_rate           51 non-null int64
# would_recommend            51 non-null int64
# dtypes: float64(28), int64(8), object(1)
# memory usage: 15.1+ KB

# %%
# Removing Extra Unnamed: 0 Index Column
del final['Unnamed: 0']

# %%
# Save and Print Final DataFrame Heading
final.to_csv('hhc_readmit_final.csv')
final.head()
# Out:
#   state  hospital_count  readmission_ratio  discharges  predicted_rate  \
# 0    AK               8           0.969563      5019.0           530.2
# 1    AL              85           1.017475     95303.0          5351.5
# 2    AR              45           1.032275     61703.0          2973.3
# 3    AZ              63           0.988116     76353.0          3930.2
# 4    CA             297           1.000689    303151.0         19823.2
#
#    expected_rate  readmissions  excessive_count  star_rating  timeliness  \
# 0          548.7         606.0               11          2.5        76.7
# 1         5308.2       15305.0              188          3.5        94.3
# 2         2879.7        9965.0              127          3.0        94.3
# 3         3990.3       10290.0              104          3.5        93.4
# 4        19733.7       49252.0              580          3.5        90.3
#
#         ...         breathing_buff  healing_buff  oral_rx_buff  \
# 0       ...                   58.8          80.4          45.8
# 1       ...                   74.5          91.3          62.5
# 2       ...                   71.7          91.8          61.1
# 3       ...                   71.3          85.8          55.2
# 4       ...                   71.9          91.9          55.5
#
#    hospital_admit  urgent_noadmit  pos_prof_report  pos_communicate_report  \
# 0            14.2            17.3               89                      85
# 1            17.5            12.2               91                      89
# 2            17.4            13.4               90                      87
# 3            14.9            13.5               87                      84
# 4            14.8            11.9               85                      83
#
#    pos_treatment_ed_report  nine_to_ten_rate  would_recommend
# 0                       81                82               81
# 1                       87                89               84
# 2                       86                87               83
# 3                       80                81               75
# 4                       82                80               74
#
# [5 rows x 36 columns]
